# %% [markdown]
# ## レポート課題4-1

# %% [markdown]
# 標準ライブラリの一つである random モジュールには，実行すると $[0,1]$ 区間の一様乱数を返す `random()` 関数が定義されています．
#
# 1. random モジュールから `random()` 関数をインポートし，10個の一様乱数（ $[0,1]$ 区間）を表示するプログラムを作成してください．
# 2. 上述のプログラムに1行以上のコードを付け加えることで，10個の乱数（1～6の整数が同確率で出現するもの）を表示するプログラムを作成してください．（これはサイコロを10回ふってその値を表示することに相当します）
#
# 上記の2つのプログラムを別々のコードセルに記入して提出すること．

# %%
import random
for index in range (10):
    print(random.random())
# Out:
# 0.14284409834245493
# 0.3150577073513502
# 0.8711682434741639
# 0.7010769017912836
# 0.1319600687366146
# 0.25379997524340914
# 0.3247321913915304
# 0.23412150661554232
# 0.9841509288506254
# 0.5791228573785338

# %%
import random
for index in range (10):
    print(random.randint(1,6))
# Out:
# 5
# 1
# 4
# 5
# 1
# 1
# 4
# 1
# 4
# 4

# %% [markdown]
# ## レポート課題4-2

# %% [markdown]
# 各自が任意の関数（float 型１つを引数にとって数値型１つを返すもの）を２つ用意し，その２つの関数のグラフを作成してください．軸の範囲，軸のラベル，凡例，プロットの色などを工夫して見やすくしてください．(他の人と異なるプログラムを評価します)

# %%
import numpy 
import matplotlib.pyplot as plt

# x軸の定義域
x = numpy.linspace(-numpy.pi, numpy.pi, 100)

# グラフのタイトル
plt.title('y = cos(tan(x)) & y = tan(x^2)')

# グラフの描画
plt.plot(x, numpy.cos(numpy.tan(x)), label='y = cos(tan(x))', color='red')
plt.plot(x, numpy.tan(x**2), label='y = tan(x^2)', color='blue')

plt.grid()

# x軸を黒線で表示
plt.axhline(0, color='black', linewidth=0.5)
# y軸を黒線で表示
plt.axvline(0, color='black', linewidth=0.5)

# 凡例の表示
plt.legend()

# 軸のラベル
plt.xlabel('x')
plt.ylabel('y')

# グラフの表示
plt.show()

# %% [markdown]
# ## レポート課題4-3

# %% [markdown]
# 各自の実行環境上でパッケージ tensorflow をモジュールとして読み込み，パスを表示するプログラムを実行してください．さらに，そのパスがファイルとフォルダ（ディレクトリ）のどちらを表しているかを調べ，フォルダである場合にはその中にあるファイルまたはフォルダの名前を（多数ある場合はいくつかに限って）報告してください．
# tensorflow が読み込めない場合，他の何らかのパッケージ1つについて同様のことを行ってください．

# %%
import matplotlib
import os

matplotlib_path = matplotlib.__path__[0]

# ディレクトリ判別
is_directory = os.path.isdir(matplotlib_path)
# ファイル判別
is_file = os.path.isfile(matplotlib_path)

if is_directory:
    print('ディレクトリです')
    result = ('ディレクトリです')
else:
    print('ディレクトリではありません.ファイルです.')
    result = ('ディレクトリではありません.ファイルです.')

matplotlib_path, result
# Out:
# ディレクトリです
# ('/Users/harukiinoue/opt/anaconda3/lib/python3.9/site-packages/matplotlib',
#  'ディレクトリです')

# %%
'/Users/harukiinoue/opt/anaconda3/lib/python3.9/site-packages/matplotlib','ディレクトリです'

# %% [markdown]
# ##########################################################################################

# %% [markdown]
# レポート課題に取り組み，プログラムと結果を.ipynb形式のファイルに保存してCoursePowerから提出しなさい．
#
# 提出ファイル名：CBReport04_学籍番号_英字氏名.ipynb
#
#  例えば，学籍番号12345678の青山太郎の場合は，CBReport04_12345678_AoyamaTaro.ipynb　というファイル名で提出する．
